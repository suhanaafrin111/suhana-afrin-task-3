# %% [markdown]
# <a href="https://colab.research.google.com/github/suhanaafrin111/suhana-afrin-task-3/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
secret_number = random.randint(1, 100)

print("welcome to the number guessing game!")
print("guess a number between 1 and 100")

while True:
  guess = int(input("enter your guesss: "))

if guess > secret_number:
   print("too high! try again. ")

elif guess < secret_number:
     print("too low! try again. ")


else:
    print("congatulations! you guessed the correct number. ")
    break
# Out:
# welcome to the number guessing game!
# guess a number between 1 and 100
# enter your guesss: 98
